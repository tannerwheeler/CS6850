# %% [markdown]
# # Hair Loss Prediction
# ## Tanner Wheeler
# ## A01770306
# ## CS 6850

# %% [markdown]
# ### Imported Libraries

# %%
import copy
import numpy as np
import pandas as pd
from pandas import crosstab
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### Reading the Data

# %%
data = pd.read_csv("PredictHairFall.csv")
data["Hair Loss"] = data["Hair Loss"].astype(bool)
classification_counts = data["Hair Loss"].value_counts()
data
# Out:
#          Id Genetics Hormonal Changes     Medical Conditions  \
# 0    133992      Yes               No                No Data
# 1    148393       No               No                 Eczema
# 2    155074       No               No             Dermatosis
# 3    118261      Yes              Yes               Ringworm
# 4    111915       No               No              Psoriasis
# ..      ...      ...              ...                    ...
# 994  184367      Yes               No  Seborrheic Dermatitis
# 995  164777      Yes              Yes                No Data
# 996  143273       No              Yes  Androgenetic Alopecia
# 997  169123       No              Yes             Dermatitis
# 998  127183      Yes              Yes              Psoriasis
#
#       Medications & Treatments Nutritional Deficiencies     Stress  Age  \
# 0                      No Data      Magnesium deficiency  Moderate   19
# 1                  Antibiotics      Magnesium deficiency      High   43
# 2             Antifungal Cream        Protein deficiency  Moderate   26
# 3                  Antibiotics        Biotin Deficiency   Moderate   46
# 4                     Accutane           Iron deficiency  Moderate   30
# ..                         ...                       ...       ...  ...
# 994                    Rogaine      Vitamin A Deficiency       Low   33
# 995                   Accutane        Protein deficiency       Low   47
# 996           Antidepressants         Protein deficiency  Moderate   20
# 997           Immunomodulators        Biotin Deficiency   Moderate   32
# 998  Blood Pressure Medication      Vitamin D Deficiency       Low   34
#
#     Poor Hair Care Habits  Environmental Factors Smoking Weight Loss   \
# 0                      Yes                   Yes      No           No
# 1                      Yes                   Yes      No           No
# 2                      Yes                   Yes      No          Yes
# 3                      Yes                   Yes      No           No
# 4                       No                   Yes     Yes           No
# ..                     ...                   ...     ...          ...
# 994                    Yes                   Yes     Yes          Yes
# 995                     No                    No      No          Yes
# 996                    Yes                    No     Yes          Yes
# 997                    Yes                   Yes     Yes          Yes
# 998                     No                   Yes      No           No
#
#      Hair Loss
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
# ..         ...
# 994       True
# 995      False
# 996       True
# 997       True
# 998       True
#
# [999 rows x 13 columns]

# %%
data_age = copy.deepcopy(data)

agelow = []
age2025 = []
age2530 = []
age3035 = []
age3540 = []
age4045 = []
agehigh = []
for index, row in data_age.iterrows():
    if row['Age'] <= 20:
        agelow.append('Yes')
    else:
        agelow.append('No')
    if row['Age'] > 20 and row['Age'] <= 25:
        age2025.append('Yes')
    else:
        age2025.append('No')
    if row['Age'] > 25 and row['Age'] <= 30:
        age2530.append('Yes')
    else:
        age2530.append('No')
    if row['Age'] > 30 and row['Age'] <= 35:
        age3035.append('Yes')
    else:
        age3035.append('No')
    if row['Age'] > 35 and row['Age'] <= 40:
        age3540.append('Yes')
    else:
        age3540.append('No')
    if row['Age'] > 40 and row['Age'] <= 45:
        age4045.append('Yes')
    else:
        age4045.append('No')
    if row['Age'] > 45:
        agehigh.append('Yes')
    else:
        agehigh.append('No')

data_age.insert(8, "Age < 20", agelow, False)
data_age.insert(9, "Age 20-25", age2025, False)
data_age.insert(10, "Age 25-30", age2530, False)
data_age.insert(11, "Age 30-35", age3035, False)
data_age.insert(12, "Age 35-40", age3540, False)
data_age.insert(13, "Age 40-45", age4045, False)
data_age.insert(14, "Age > 45", agehigh, False)
data_age
# Out:
#          Id Genetics Hormonal Changes     Medical Conditions  \
# 0    133992      Yes               No                No Data
# 1    148393       No               No                 Eczema
# 2    155074       No               No             Dermatosis
# 3    118261      Yes              Yes               Ringworm
# 4    111915       No               No              Psoriasis
# ..      ...      ...              ...                    ...
# 994  184367      Yes               No  Seborrheic Dermatitis
# 995  164777      Yes              Yes                No Data
# 996  143273       No              Yes  Androgenetic Alopecia
# 997  169123       No              Yes             Dermatitis
# 998  127183      Yes              Yes              Psoriasis
#
#       Medications & Treatments Nutritional Deficiencies     Stress  Age  \
# 0                      No Data      Magnesium deficiency  Moderate   19
# 1                  Antibiotics      Magnesium deficiency      High   43
# 2             Antifungal Cream        Protein deficiency  Moderate   26
# 3                  Antibiotics        Biotin Deficiency   Moderate   46
# 4                     Accutane           Iron deficiency  Moderate   30
# ..                         ...                       ...       ...  ...
# 994                    Rogaine      Vitamin A Deficiency       Low   33
# 995                   Accutane        Protein deficiency       Low   47
# 996           Antidepressants         Protein deficiency  Moderate   20
# 997           Immunomodulators        Biotin Deficiency   Moderate   32
# 998  Blood Pressure Medication      Vitamin D Deficiency       Low   34
#
#     Age < 20 Age 20-25 Age 25-30 Age 30-35 Age 35-40 Age 40-45 Age > 45  \
# 0        Yes        No        No        No        No        No       No
# 1         No        No        No        No        No       Yes       No
# 2         No        No       Yes        No        No        No       No
# 3         No        No        No        No        No        No      Yes
# 4         No        No       Yes        No        No        No       No
# ..       ...       ...       ...       ...       ...       ...      ...
# 994       No        No        No       Yes        No        No       No
# 995       No        No        No        No        No        No      Yes
# 996      Yes        No        No        No        No        No       No
# 997       No        No        No       Yes        No        No       No
# 998       No        No        No       Yes        No        No       No
#
#     Poor Hair Care Habits  Environmental Factors Smoking Weight Loss   \
# 0                      Yes                   Yes      No           No
# 1                      Yes                   Yes      No           No
# 2                      Yes                   Yes      No          Yes
# 3                      Yes                   Yes      No           No
# 4                       No                   Yes     Yes           No
# ..                     ...                   ...     ...          ...
# 994                    Yes                   Yes     Yes          Yes
# 995                     No                    No      No          Yes
# 996                    Yes                    No     Yes          Yes
# 997                    Yes                   Yes     Yes          Yes
# 998                     No                   Yes      No           No
#
#      Hair Loss
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
# ..         ...
# 994       True
# 995      False
# 996       True
# 997       True
# 998       True
#
# [999 rows x 20 columns]

# %%
classification_counts
# Out:
# Hair Loss
# False    502
# True     497
# Name: count, dtype: int64

# %% [markdown]
# #### Checking for any Null or NaN values in the Data Frame

# %%
data.isnull().any().any()
# Out:
# False

# %% [markdown]
# #### Checking for duplicate Ids

# %%
duplicates = data[data["Id"].duplicated(keep=False)]

# %%
duplicates
# Out:
#          Id Genetics Hormonal Changes     Medical Conditions  \
# 118  172639      Yes              Yes  Androgenetic Alopecia
# 237  157627      Yes               No             Dermatosis
# 388  110171      Yes               No       Thyroid Problems
# 408  110171       No               No              Psoriasis
# 600  157627       No               No       Thyroid Problems
# 669  186979       No               No  Seborrheic Dermatitis
# 866  172639      Yes              Yes                No Data
# 956  186979      Yes              Yes  Seborrheic Dermatitis
#
#       Medications & Treatments Nutritional Deficiencies     Stress  Age  \
# 118          Heart Medication            Iron deficiency  Moderate   29
# 237                    Rogaine        Protein deficiency  Moderate   47
# 388           Antifungal Cream       Selenium deficiency       Low   25
# 408           Immunomodulators      Vitamin E deficiency       Low   41
# 600                   Accutane        Protein deficiency  Moderate   44
# 669  Blood Pressure Medication      Vitamin E deficiency  Moderate   41
# 866                   Accutane      Vitamin A Deficiency       Low   47
# 956               Chemotherapy                   No Data  Moderate   21
#
#     Poor Hair Care Habits  Environmental Factors Smoking Weight Loss   \
# 118                    Yes                    No     Yes           No
# 237                    Yes                    No     Yes          Yes
# 388                    Yes                    No     Yes          Yes
# 408                    Yes                    No      No          Yes
# 600                    Yes                   Yes     Yes          Yes
# 669                     No                    No      No           No
# 866                    Yes                    No      No          Yes
# 956                     No                    No     Yes           No
#
#      Hair Loss
# 118       True
# 237       True
# 388      False
# 408      False
# 600      False
# 669       True
# 866      False
# 956       True

# %%
data.describe(include='all').transpose()
# Out:
#                            count unique              top freq           mean  \
# Id                         999.0    NaN              NaN  NaN  153354.673674
# Genetics                     999      2              Yes  522            NaN
# Hormonal Changes             999      2              Yes  509            NaN
# Medical Conditions           999     11          No Data  110            NaN
# Medications & Treatments     999     11          Rogaine  116            NaN
# Nutritional Deficiencies     999     11  Zinc Deficiency  108            NaN
# Stress                       999      3         Moderate  351            NaN
# Age                        999.0    NaN              NaN  NaN      34.188188
# Poor Hair Care Habits        999      2               No  507            NaN
# Environmental Factors        999      2              Yes  508            NaN
# Smoking                      999      2              Yes  519            NaN
# Weight Loss                  999      2               No  527            NaN
# Hair Loss                    999      2            False  502            NaN
#
#                                     std       min       25%       50%  \
# Id                         25516.041985  110003.0  131867.5  152951.0
# Genetics                            NaN       NaN       NaN       NaN
# Hormonal Changes                    NaN       NaN       NaN       NaN
# Medical Conditions                  NaN       NaN       NaN       NaN
# Medications & Treatments            NaN       NaN       NaN       NaN
# Nutritional Deficiencies            NaN       NaN       NaN       NaN
# Stress                              NaN       NaN       NaN       NaN
# Age                             9.37798      18.0      26.0      34.0
# Poor Hair Care Habits               NaN       NaN       NaN       NaN
# Environmental Factors               NaN       NaN       NaN       NaN
# Smoking                             NaN       NaN       NaN       NaN
# Weight Loss                         NaN       NaN       NaN       NaN
# Hair Loss                           NaN       NaN       NaN       NaN
#
#                                 75%       max
# Id                         174969.0  199949.0
# Genetics                        NaN       NaN
# Hormonal Changes                NaN       NaN
# Medical Conditions              NaN       NaN
# Medications & Treatments        NaN       NaN
# Nutritional Deficiencies        NaN       NaN
# Stress                          NaN       NaN
# Age                            42.0      50.0
# Poor Hair Care Habits           NaN       NaN
# Environmental Factors           NaN       NaN
# Smoking                         NaN       NaN
# Weight Loss                     NaN       NaN
# Hair Loss                       NaN       NaN

# %% [markdown]
# #### Plot the different values

# %%
keys = [i for i in data.keys()]
keys.pop(0)
keys.pop(6)

for cat in keys:
    X = data[cat].unique()
    yes_list = []
    no_list = []
    for a in data[cat].unique():
        temp = data[data[cat] == a]
        yes_list.append(len(temp[temp['Hair Loss'] == True]))
        no_list.append(len(temp[temp['Hair Loss'] == False]))

    X_axis = np.arange(len(X))
    
    plt.bar(X_axis - 0.2, yes_list, 0.4, label='Hair Loss = True')
    plt.bar(X_axis + 0.2, no_list, 0.4, label='Hair Loss = False')
    
    plt.xticks(X_axis, X, rotation=90)
    plt.xlabel("Hair Loss")
    plt.ylabel("Number with Hair Loss")
    plt.title("Number of People with Hair Loss Given " + str(cat))
    plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
    plt.show()

# %%
keys = [i for i in data_age.keys()]
keys.pop(0)
keys.pop(6)

for cat in keys:
    X = data_age[cat].unique()
    yes_list = []
    no_list = []
    for a in data_age[cat].unique():
        temp = data_age[data_age[cat] == a]
        yes_list.append(len(temp[temp['Hair Loss'] == True]))
        no_list.append(len(temp[temp['Hair Loss'] == False]))

    X_axis = np.arange(len(X))
    
    plt.bar(X_axis - 0.2, yes_list, 0.4, label='Hair Loss = True')
    plt.bar(X_axis + 0.2, no_list, 0.4, label='Hair Loss = False')
    
    plt.xticks(X_axis, X, rotation=90)
    plt.xlabel("Hair Loss")
    plt.ylabel("Number with Hair Loss")
    plt.title("Number of People with Hair Loss Given " + str(cat))
    plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
    plt.show()

# %%
values = data['Age']
plt.hist(values, bins=range(18, 52, 2), edgecolor="black", density=True)
plt.xlabel("Age")
plt.ylabel("Density")
plt.title("Ages of people in the data")
plt.show()

values = data[data['Hair Loss'] == True]['Age']
plt.hist(values, bins=range(18, 52, 2), edgecolor="black", density=True)
plt.xlabel("Age")
plt.ylabel("Density")
plt.title("Ages of people in the data w/ Hair Loss")
plt.show()

values = data[data['Hair Loss'] == False]['Age']
plt.hist(values, bins=range(18, 52, 2), edgecolor="black", density=True)
plt.xlabel("Age")
plt.ylabel("Density")
plt.title("Ages of people in the data w/o Hair Loss")
plt.show()

# %%
xs = [i for i in data.keys()]
xs.pop(0)

#print(xs)

for x in range(len(xs)):
    for y in range(x,len(xs)):
        if xs[x] != xs[y] and xs[x] != "Id" and xs[y] != "Id" and xs[x] != "Age" and xs[y] != "Age" and xs[x] != "Hair Loss" and xs[y] != "Hair Loss":
            data2 = data[[xs[x],xs[y]]]
            freq = crosstab(data2[xs[x]], data2[xs[y]])
            #print(freq)
            #print()
            total = freq.sum().sum()
            Pxy = round(freq/total,2)
            #print(Pxy)
            #print()
            Px = freq.sum(axis=1)/total
            Px = pd.DataFrame([Px for i in range(len(data2[xs[y]].unique()))], index=Pxy.columns).transpose()
            Py = freq.sum(axis=0)/total
            Py = pd.DataFrame([Py for i in range(len(data2[xs[x]].unique()))], index=Pxy.index).transpose()
            temp = Pxy/Px
            temp = temp/Py
            temp = Pxy*np.log(temp)/np.log(2)
            print("Mutual Information between " + xs[x] + " and " + xs[y] + ":", temp.sum().sum())
# Out:
# Mutual Information between Genetics and Hormonal Changes: -0.00021701119930679462
# /home/tannerwheeler/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:366: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# /home/tannerwheeler/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:366: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# /home/tannerwheeler/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:366: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)

# %%
xs = [i for i in data_age.keys()]
xs.pop(0)

#print(xs)

for x in range(len(xs)):
    for y in range(x,len(xs)):
        if xs[x] != xs[y] and xs[x] != "Id" and xs[y] != "Id" and xs[x] != "Age" and xs[y] != "Age" and xs[x] != "Hair Loss" and xs[y] != "Hair Loss":
            data2_age = data_age[[xs[x],xs[y]]]
            freq = crosstab(data2_age[xs[x]], data2_age[xs[y]])
            #print(freq)
            #print()
            total = freq.sum().sum()
            Pxy = round(freq/total,2)
            #print(Pxy)
            #print()
            Px = freq.sum(axis=1)/total
            Px = pd.DataFrame([Px for i in range(len(data2_age[xs[y]].unique()))], index=Pxy.columns).transpose()
            Py = freq.sum(axis=0)/total
            Py = pd.DataFrame([Py for i in range(len(data2_age[xs[x]].unique()))], index=Pxy.index).transpose()
            temp = Pxy/Px
            temp = temp/Py
            temp = Pxy*np.log(temp)/np.log(2)
            print("Mutual Information between " + xs[x] + " and " + xs[y] + ":", temp.sum().sum())
# Out:
# Mutual Information between Genetics and Hormonal Changes: -0.00021701119930679462
# Mutual Information between Genetics and Medical Conditions: 0.0
# Mutual Information between Genetics and Medications & Treatments: 0.0
# Mutual Information between Genetics and Nutritional Deficiencies : 0.0
# Mutual Information between Genetics and Stress: 0.0
# Mutual Information between Genetics and Age < 20: 1.4660479095068772
# Mutual Information between Genetics and Age 20-25: 1.0161502692409856
# Mutual Information between Genetics and Age 25-30: 0.9130013596512292
# Mutual Information between Genetics and Age 30-35: 0.8146435480419181
# Mutual Information between Genetics and Age 35-40: 0.8765539710059137
# Mutual Information between Genetics and Age 40-45: 0.9401149339872445
# Mutual Information between Genetics and Age > 45: 0.9296089218166292
# Mutual Information between Genetics and Poor Hair Care Habits : 0.0016026095470909694
# Mutual Information between Genetics and Environmental Factors: -0.00019977790747967641
# Mutual Information between Genetics and Smoking: 0.0012718803231969167
# Mutual Information between Genetics and Weight Loss : 0.02252731821249435
# Mutual Information between Hormonal Changes and Medical Conditions: 0.0
# Mutual Information between Hormonal Changes and Medications & Treatments: 0.0
# Mutual Information between Hormonal Changes and Nutritional Deficiencies : 0.0
# Mutual Information between Hormonal Changes and Stress: 0.0
# Mutual Information between Hormonal Changes and Age < 20: 1.4321797726888568
# Mutual Information between Hormonal Changes and Age 20-25: 0.9773662406744827
# Mutual Information between Hormonal Changes and Age 25-30: 0.8652719562062191
# Mutual Information between Hormonal Changes and Age 30-35: 0.7922204209908531
# Mutual Information between Hormonal Changes and Age 35-40: 0.8683044049403574
# Mutual Information between Hormonal Changes and Age 40-45: 0.9024255058848663
# Mutual Information between Hormonal Changes and Age > 45: 0.9196813036316115
# Mutual Information between Hormonal Changes and Poor Hair Care Habits : 0.002017540719571437
# Mutual Information between Hormonal Changes and Environmental Factors: 0.0011857597024057878
# Mutual Information between Hormonal Changes and Smoking: 0.001394824263527373
# Mutual Information between Hormonal Changes and Weight Loss : 0.021107882231781443
# Mutual Information between Medical Conditions and Medications & Treatments: 0.0
# Mutual Information between Medical Conditions and Nutritional Deficiencies : 0.0
# Mutual Information between Medical Conditions and Stress: 0.0
# Mutual Information between Medical Conditions and Age < 20: 0.0
# Mutual Information between Medical Conditions and Age 20-25: 0.0
# Mutual Information between Medical Conditions and Age 25-30: 0.0
# Mutual Information between Medical Conditions and Age 30-35: 0.0
# /home/tannerwheeler/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:366: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# /home/tannerwheeler/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:366: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# /home/tannerwheeler/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:366: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# /home/tannerwheeler/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:366: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# /home/tannerwheeler/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:366: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)

# %% [markdown]
# #### Decision Trees

# %%
results = data['Hair Loss']
data = data.drop(columns=['Id', 'Hair Loss'])

# %%
results_age = data_age['Hair Loss']
data_age = data_age.drop(columns=['Id', 'Hair Loss'])

# %% [markdown]
# Finding the best Tree Depth and Test Set size

# %%
for i in range(1, 10):
    # Using a Random State for consistancy in initial testing
    X_train, X_test, Y_train, Y_test = train_test_split(data, results, test_size=i/10, random_state=1)
    
    le = preprocessing.LabelEncoder()
    for column_name in X_train.columns:
        if X_train[column_name].dtype == object:
            X_train[column_name] = le.fit_transform(X_train[column_name])
        else:
            pass
    
    for column_name in X_test.columns:
        if X_test[column_name].dtype == object:
            X_test[column_name] = le.fit_transform(X_test[column_name])
        else:
            pass
            
    maxdepths = [2,3,4,5,6,7,8,9,10,15,20]
    
    trainAcc = np.zeros(len(maxdepths))
    testAcc = np.zeros(len(maxdepths))
    index = 0
    
    for depth in maxdepths:
        clf = tree.DecisionTreeClassifier(max_depth=depth)
        clf = clf.fit(X_train, Y_train)
        Y_predTrain = clf.predict(X_train)
        Y_predTest = clf.predict(X_test)
        trainAcc[index] = accuracy_score(Y_train, Y_predTrain)
        testAcc[index] = accuracy_score(Y_test, Y_predTest)
        index += 1
    
    plt.plot(maxdepths, trainAcc, 'ro-', maxdepths, testAcc, 'bv--')
    plt.legend(['Training Accuracy', 'Test Accuracy'])
    plt.xlabel('Tree Depth Maximumm')
    plt.ylabel('Accuracy')
    plt.title('Tree Depth Accuracies with X_test size = ' + str(i/10))
    plt.show()

# %%
for i in range(1, 10):
    # Using a Random State for consistancy in initial testing
    X_train, X_test, Y_train, Y_test = train_test_split(data_age, results, test_size=i/10, random_state=1)
    
    le = preprocessing.LabelEncoder()
    for column_name in X_train.columns:
        if X_train[column_name].dtype == object:
            X_train[column_name] = le.fit_transform(X_train[column_name])
        else:
            pass
    
    for column_name in X_test.columns:
        if X_test[column_name].dtype == object:
            X_test[column_name] = le.fit_transform(X_test[column_name])
        else:
            pass
            
    maxdepths = [2,3,4,5,6,7,8,9,10,15,20]
    
    trainAcc = np.zeros(len(maxdepths))
    testAcc = np.zeros(len(maxdepths))
    index = 0
    
    for depth in maxdepths:
        clf = tree.DecisionTreeClassifier(max_depth=depth)
        clf = clf.fit(X_train, Y_train)
        Y_predTrain = clf.predict(X_train)
        Y_predTest = clf.predict(X_test)
        trainAcc[index] = accuracy_score(Y_train, Y_predTrain)
        testAcc[index] = accuracy_score(Y_test, Y_predTest)
        index += 1
    
    plt.plot(maxdepths, trainAcc, 'ro-', maxdepths, testAcc, 'bv--')
    plt.legend(['Training Accuracy', 'Test Accuracy'])
    plt.xlabel('Tree Depth Maximumm')
    plt.ylabel('Accuracy')
    plt.title('Tree Depth Accuracies with X_test size = ' + str(i/10))
    plt.show()

# %% [markdown]
# 5-Fold Cross Validation with Decision Tree

# %%
df = data
r = results

le = preprocessing.LabelEncoder()
for column_name in df.columns:
    if df[column_name].dtype == object:
        df[column_name] = le.fit_transform(df[column_name])
    else:
        pass

clf = tree.DecisionTreeClassifier(max_depth=6)
scores = cross_val_score(clf, df, r, cv=5)
data
# Out:
#      Genetics  Hormonal Changes  Medical Conditions  Medications & Treatments  \
# 0           1                 0                   5                         8
# 1           0                 0                   4                         1
# 2           0                 0                   3                         3
# 3           1                 1                   7                         1
# 4           0                 0                   6                         0
# ..        ...               ...                 ...                       ...
# 994         1                 0                   9                         9
# 995         1                 1                   5                         0
# 996         0                 1                   1                         2
# 997         0                 1                   2                         7
# 998         1                 1                   6                         4
#
#      Nutritional Deficiencies   Stress  Age  Poor Hair Care Habits   \
# 0                            2       2   19                       1
# 1                            2       0   43                       1
# 2                            5       2   26                       1
# 3                            0       2   46                       1
# 4                            1       2   30                       0
# ..                         ...     ...  ...                     ...
# 994                          7       1   33                       1
# 995                          5       1   47                       0
# 996                          5       2   20                       1
# 997                          0       2   32                       1
# 998                          8       1   34                       0
#
#      Environmental Factors  Smoking  Weight Loss
# 0                        1        0             0
# 1                        1        0             0
# 2                        1        0             1
# 3                        1        0             0
# 4                        1        1             0
# ..                     ...      ...           ...
# 994                      1        1             1
# 995                      0        0             1
# 996                      0        1             1
# 997                      1        1             1
# 998                      1        0             0
#
# [999 rows x 11 columns]

# %%
print('Accuracy: %0.2f (+/- %0.2f)' % (scores.mean(), scores.std()*2))
# Out:
# Accuracy: 0.52 (+/- 0.06)

# %%
df = data_age
r = results_age

le = preprocessing.LabelEncoder()
for column_name in df.columns:
    if df[column_name].dtype == object:
        df[column_name] = le.fit_transform(df[column_name])
    else:
        pass

clf = tree.DecisionTreeClassifier(max_depth=6)
scores = cross_val_score(clf, df, r, cv=5)
data_age
# Out:
#      Genetics  Hormonal Changes  Medical Conditions  Medications & Treatments  \
# 0           1                 0                   5                         8
# 1           0                 0                   4                         1
# 2           0                 0                   3                         3
# 3           1                 1                   7                         1
# 4           0                 0                   6                         0
# ..        ...               ...                 ...                       ...
# 994         1                 0                   9                         9
# 995         1                 1                   5                         0
# 996         0                 1                   1                         2
# 997         0                 1                   2                         7
# 998         1                 1                   6                         4
#
#      Nutritional Deficiencies   Stress  Age  Age < 20  Age 20-25  Age 25-30  \
# 0                            2       2   19         1          0          0
# 1                            2       0   43         0          0          0
# 2                            5       2   26         0          0          1
# 3                            0       2   46         0          0          0
# 4                            1       2   30         0          0          1
# ..                         ...     ...  ...       ...        ...        ...
# 994                          7       1   33         0          0          0
# 995                          5       1   47         0          0          0
# 996                          5       2   20         1          0          0
# 997                          0       2   32         0          0          0
# 998                          8       1   34         0          0          0
#
#      Age 30-35  Age 35-40  Age 40-45  Age > 45  Poor Hair Care Habits   \
# 0            0          0          0         0                       1
# 1            0          0          1         0                       1
# 2            0          0          0         0                       1
# 3            0          0          0         1                       1
# 4            0          0          0         0                       0
# ..         ...        ...        ...       ...                     ...
# 994          1          0          0         0                       1
# 995          0          0          0         1                       0
# 996          0          0          0         0                       1
# 997          1          0          0         0                       1
# 998          1          0          0         0                       0
#
#      Environmental Factors  Smoking  Weight Loss
# 0                        1        0             0
# 1                        1        0             0
# 2                        1        0             1
# 3                        1        0             0
# 4                        1        1             0
# ..                     ...      ...           ...
# 994                      1        1             1
# 995                      0        0             1
# 996                      0        1             1
# 997                      1        1             1
# 998                      1        0             0
#
# [999 rows x 18 columns]

# %%
print('Accuracy: %0.2f (+/- %0.2f)' % (scores.mean(), scores.std()*2))
# Out:
# Accuracy: 0.51 (+/- 0.05)

# %% [markdown]
# #### Random Forest Classifier

# %%
for i in range(1, 10):
    # Using a Random State for consistancy in initial testing
    X_train, X_test, Y_train, Y_test = train_test_split(data, results, test_size=i/10, random_state=1)
    
    le = preprocessing.LabelEncoder()
    for column_name in X_train.columns:
        if X_train[column_name].dtype == object:
            X_train[column_name] = le.fit_transform(X_train[column_name])
        else:
            pass
    
    for column_name in X_test.columns:
        if X_test[column_name].dtype == object:
            X_test[column_name] = le.fit_transform(X_test[column_name])
        else:
            pass
            
    maxdepths = [2,3,4,5,6,7,8,9,10,15,20]
    
    trainAcc = np.zeros(len(maxdepths))
    testAcc = np.zeros(len(maxdepths))
    index = 0
    
    for depth in maxdepths:
        # Using a Random State for consistancy in initial testing
        clf = RandomForestClassifier(max_depth=depth, random_state=0)
        clf = clf.fit(X_train, Y_train)
        Y_predTrain = clf.predict(X_train)
        Y_predTest = clf.predict(X_test)
        trainAcc[index] = accuracy_score(Y_train, Y_predTrain)
        testAcc[index] = accuracy_score(Y_test, Y_predTest)
        index += 1
    
    plt.plot(maxdepths, trainAcc, 'ro-', maxdepths, testAcc, 'bv--')
    plt.legend(['Training Accuracy', 'Test Accuracy'])
    plt.xlabel('Tree Depth Maximumm')
    plt.ylabel('Accuracy')
    plt.title('Tree Depth Accuracies with X_test size = ' + str(i/10))
    plt.show()

# %%
for i in range(1, 10):
    # Using a Random State for consistancy in initial testing
    X_train, X_test, Y_train, Y_test = train_test_split(data_age, results, test_size=i/10, random_state=1)
    
    le = preprocessing.LabelEncoder()
    for column_name in X_train.columns:
        if X_train[column_name].dtype == object:
            X_train[column_name] = le.fit_transform(X_train[column_name])
        else:
            pass
    
    for column_name in X_test.columns:
        if X_test[column_name].dtype == object:
            X_test[column_name] = le.fit_transform(X_test[column_name])
        else:
            pass
            
    maxdepths = [2,3,4,5,6,7,8,9,10,15,20]
    
    trainAcc = np.zeros(len(maxdepths))
    testAcc = np.zeros(len(maxdepths))
    index = 0
    
    for depth in maxdepths:
        # Using a Random State for consistancy in initial testing
        clf = RandomForestClassifier(max_depth=depth, random_state=0)
        clf = clf.fit(X_train, Y_train)
        Y_predTrain = clf.predict(X_train)
        Y_predTest = clf.predict(X_test)
        trainAcc[index] = accuracy_score(Y_train, Y_predTrain)
        testAcc[index] = accuracy_score(Y_test, Y_predTest)
        index += 1
    
    plt.plot(maxdepths, trainAcc, 'ro-', maxdepths, testAcc, 'bv--')
    plt.legend(['Training Accuracy', 'Test Accuracy'])
    plt.xlabel('Tree Depth Maximumm')
    plt.ylabel('Accuracy')
    plt.title('Tree Depth Accuracies with X_test size = ' + str(i/10))
    plt.show()

# %% [markdown]
# 5-Fold Cross Validation with Random Forests

# %%
df = data
r = results

clf = RandomForestClassifier(max_depth=7, random_state=0)
scores = cross_val_score(clf, df, r, cv=5)

# %%
print('Accuracy: %0.2f (+/- %0.2f)' % (scores.mean(), scores.std()*2))
# Out:
# Accuracy: 0.51 (+/- 0.03)

# %%
df = data_age
r = results_age

clf = RandomForestClassifier(max_depth=7, random_state=0)
scores = cross_val_score(clf, df, r, cv=5)

# %%
print('Accuracy: %0.2f (+/- %0.2f)' % (scores.mean(), scores.std()*2))
# Out:
# Accuracy: 0.49 (+/- 0.05)

# %% [markdown]
# Hypertuning on the data. Random Forests also needs to have a spread of multiple trees as a variable that should be changed. Try to decrease the distance between the accuracy in training and accuracy in testing.
